# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset("titanic")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df=df.dropna(subset=['deck'])

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           1       1  female  38.0      1      0  71.2833        C  First
# 1           1       1  female  35.0      1      0  53.1000        S  First
# 2           0       1    male  54.0      0      0  51.8625        S  First
# 3           1       3  female   4.0      1      1  16.7000        S  Third
# 4           1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 198         1       1  female  47.0      1      1  52.5542        S  First
# 199         0       1    male  33.0      0      0   5.0000        S  First
# 200         1       1  female  56.0      0      1  83.1583        C  First
# 201         1       1  female  19.0      0      0  30.0000        S  First
# 202         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  203.000000  203.000000  184.000000  203.000000  203.000000  203.000000
# mean     0.669951    1.197044   35.779457    0.443350    0.438424   76.341708
# std      0.471393    0.527080   15.707436    0.629704    0.731133   74.520547
# min      0.000000    1.000000    0.920000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   24.000000    0.000000    0.000000   29.206250
# 50%      1.000000    1.000000   36.000000    0.000000    0.000000   55.441700
# 75%      1.000000    1.000000   48.000000    1.000000    1.000000   89.552100
# max      1.000000    3.000000   80.000000    3.000000    4.000000  512.329200

# %%
df['survived'].value_counts().plot(kind='bar')
plt.title('test plot',fontsize=8,color='y')
plt.xlabel('Analysis')
plt.ylabel('values')
plt.show()

# %%
df[['survived','pclass','age','sibsp','parch','fare']].mean().plot(kind='bar')
plt.title('test plot',fontsize=8,color='red')
plt.xlabel('columns')
plt.ylabel('Mean')
plt.show()

# %%
new_df=df.select_dtypes(include=['number'])
new_df
# Out:
#      survived  pclass   age  sibsp  parch     fare
# 0           1       1  38.0      1      0  71.2833
# 1           1       1  35.0      1      0  53.1000
# 2           0       1  54.0      0      0  51.8625
# 3           1       3   4.0      1      1  16.7000
# 4           1       1  58.0      0      0  26.5500
# ..        ...     ...   ...    ...    ...      ...
# 198         1       1  47.0      1      1  52.5542
# 199         0       1  33.0      0      0   5.0000
# 200         1       1  56.0      0      1  83.1583
# 201         1       1  19.0      0      0  30.0000
# 202         1       1  26.0      0      0  30.0000
#
# [203 rows x 6 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
new_df=scaler.fit_transform(new_df)

# %%
new_df
# Out:
# array([[ 0.70188821, -0.37476584,  0.14175466,  0.8861723 , -0.60113184,
#         -0.06804719],
#        [ 0.70188821, -0.37476584, -0.04975881,  0.8861723 , -0.60113184,
#         -0.31265426],
#        [-1.42472831, -0.37476584,  1.16315986, -0.70580095, -0.60113184,
#         -0.32930147],
#        ...,
#        [ 0.70188821, -0.37476584,  1.2908355 , -0.70580095,  0.7699891 ,
#          0.09169878],
#        [ 0.70188821, -0.37476584, -1.071164  , -0.70580095, -0.60113184,
#         -0.62340222],
#        [ 0.70188821, -0.37476584, -0.62429923, -0.70580095, -0.60113184,
#         -0.62340222]])

# %%
row_means=np.mean(new_df,axis=1)
x=np.arange(len(row_means))

# %%
plt.subplot(1,2,1)
plt.bar(x,row_means,color='gray')
plt.title("Row-wise Mean",color='red')
plt.xlabel("Row index")
plt.ylabel("Mean value")
plt.show()

# %%
row_std=np.std(new_df,axis=1)
plt.subplot(1,2,1)
plt.bar(x,row_std,color='gray')
plt.title("Row-wise Mean",color='red')
plt.xlabel("Row index")
plt.ylabel("Mean value")
plt.show()

# %%
df_melted = df[['survived','pclass','age','sibsp','parch','fare']].melt(var_name="feature", value_name="values")
plt.figure(figsize=(12,8))
sns.boxplot(x="feature", y="values", data=df_melted)
plt.title("Box plot of Features")
plt.show()

# %%
ndf=df.set_index('sex')

# %%
ndf
# Out:
#         survived  pclass   age  sibsp  parch     fare embarked  class    who  \
# sex
# female         1       1  38.0      1      0  71.2833        C  First  woman
# female         1       1  35.0      1      0  53.1000        S  First  woman
# male           0       1  54.0      0      0  51.8625        S  First    man
# female         1       3   4.0      1      1  16.7000        S  Third  child
# female         1       1  58.0      0      0  26.5500        S  First  woman
# ...          ...     ...   ...    ...    ...      ...      ...    ...    ...
# female         1       1  47.0      1      1  52.5542        S  First  woman
# male           0       1  33.0      0      0   5.0000        S  First    man
# female         1       1  56.0      0      1  83.1583        C  First  woman
# female         1       1  19.0      0      0  30.0000        S  First  woman
# male           1       1  26.0      0      0  30.0000        C  First    man
#
# ...

# %%
ndf=ndf.select_dtypes(include=['number'])
ndf
# Out:
#         survived  pclass   age  sibsp  parch     fare
# sex
# female         1       1  38.0      1      0  71.2833
# female         1       1  35.0      1      0  53.1000
# male           0       1  54.0      0      0  51.8625
# female         1       3   4.0      1      1  16.7000
# female         1       1  58.0      0      0  26.5500
# ...          ...     ...   ...    ...    ...      ...
# female         1       1  47.0      1      1  52.5542
# male           0       1  33.0      0      0   5.0000
# female         1       1  56.0      0      1  83.1583
# female         1       1  19.0      0      0  30.0000
# male           1       1  26.0      0      0  30.0000
#
# [203 rows x 6 columns]

# %%
plt.figure(figsize=(12, 8))
sns.violinplot(x="sex", y="age", data=df)   # pick a numeric column for y: age, fare, etc.
plt.title("Box plot of Age by Gender")
plt.xlabel("Sex")
plt.ylabel("Age")
plt.show()

# %%
corr = df.corr(numeric_only=True)  
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of Titanic Features")
plt.show()

# %%
corr = df.corr(numeric_only=True)  
plt.figure(figsize=(8,6))
sns.clustermap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of Titanic Features")
plt.show()

# %%
df=df.set_index('age')
df
# Out:
#       survived  pclass     sex  sibsp  parch     fare embarked  class    who  \
# age
# 38.0         1       1  female      1      0  71.2833        C  First  woman
# 35.0         1       1  female      1      0  53.1000        S  First  woman
# 54.0         0       1    male      0      0  51.8625        S  First    man
# 4.0          1       3  female      1      1  16.7000        S  Third  child
# 58.0         1       1  female      0      0  26.5500        S  First  woman
# ...        ...     ...     ...    ...    ...      ...      ...    ...    ...
# 47.0         1       1  female      1      1  52.5542        S  First  woman
# 33.0         0       1    male      0      0   5.0000        S  First    man
# 56.0         1       1  female      0      1  83.1583        C  First  woman
# 19.0         1       1  female      0      0  30.0000        S  First  woman
# 26.0         1       1    male      0      0  30.0000        C  First    man
#
# ...

# %%
corr = df.corr(numeric_only=True)  
plt.figure(figsize=(8,6))
sns.kdeplot(corr)
plt.xlabel('age')
plt.ylabel('values')
# Out:
# Text(0, 0.5, 'values')

# %%
corr = df.corr(numeric_only=True)  
plt.figure(figsize=(8,6))
sns.scatterplot(corr)
plt.xlabel('age')
plt.ylabel('values')
# Out:
# Text(0, 0.5, 'values')
